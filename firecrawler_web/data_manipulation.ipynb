# %%
import pandas as pd

# %%
import pandas as pd
import json

df = pd.read_json('Scraped_data/Data_1.json')
print(df.head())

# %%
import json
import pandas as pd

with open("Scraped_Data/Data_1.json", "r", encoding="utf-8") as f:
    data = json.load(f)


df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in data.items()]))

df
df.isnull()

# %%
import json
import pandas as pd

with open("Scraped_Data/Data_1.json", "r", encoding="utf-8") as f:
    data = json.load(f)


df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in data.items()]))

df.columns
df.publishedDate
# Out:
# 0    5 days ago
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# Name: publishedDate, dtype: object
